# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv("D:/restaurant_dataset.csv")
print(data.head(1))
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
#
#                                     Locality  \
# 0  Century City Mall, Poblacion, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
#
#                      Cuisines  ...          Currency Has Table booking  \
# 0  French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
#
#    Aggregate rating  Rating color Rating text Votes
# 0               4.8    Dark Green   Excellent   314
#
# [1 rows x 21 columns]

# %% [markdown]
# # Task4: Restaurant Chains

# %% [markdown]
# ## Identify if there are any restaurant chains present in the dataset.

# %%
restaurant_counts = data['Restaurant Name'].value_counts()
restaurant_chains = restaurant_counts[restaurant_counts > 1]
print("Restaurant Chains:")
print(restaurant_chains)
print("\nNumber of unique restaurant chains:", len(restaurant_chains))
# Out:
# Restaurant Chains:
# Restaurant Name
# Cafe Coffee Day     83
# Domino's Pizza      79
# Subway              63
# Green Chick Chop    51
# McDonald's          48
#                     ..
# Olive Bistro         2
# Vaishno Rasoi        2
# Shalimar Vyanjan     2
# Otik Cake Shop       2
# Gullu's              2
# Name: count, Length: 735, dtype: int64
#
# Number of unique restaurant chains: 735

# %% [markdown]
# ## Analyze the ratings and popularity of different restaurant chains.

# %%
Ratings = data.groupby('Restaurant Name')['Aggregate rating'].mean().reset_index(name="Average Rating").sort_values(by="Average Rating", ascending=False)
print(Ratings)
# Out:
#                     Restaurant Name  Average Rating
# 6264               Talaga Sampireun             4.9
# 1300                    Caterspoint             4.9
# 4648                   Oakwood Cafe             4.9
# 5758        Shorts Burger and Shine             4.9
# 3960      Mainland China Restaurant             4.9
# ...                             ...             ...
# 4671         Old Delhi Food Factory             0.0
# 4673                 Old Kheer Shop             0.0
# 4674  Old Moradabadi Chicken Corner             0.0
# 1454                Chefy's Kitchen             0.0
# 3722                    Laxmi Dairy             0.0
#
# [7445 rows x 2 columns]

# %%
plt.figure(figsize=(8, 4))
plt.barh(Ratings["Restaurant Name"][:10], Ratings["Average Rating"][:10],color='lightgreen', edgecolor='black')
plt.title("Top 10 Restaurant Chains by Average Rating")
plt.xlabel("Average Rating")
plt.ylabel("Restaurant Chains")
plt.show()

# %%
Votes = data.groupby('Restaurant Name')['Votes'].sum().reset_index(name='Total Votes').sort_values(by='Total Votes', ascending=False)
print(Votes)
# Out:
#                 Restaurant Name  Total Votes
# 665             Barbeque Nation        28142
# 103   AB's - Absolute Barbecues        13400
# 6944                       Toit        10934
# 787                   Big Chill        10853
# 2299                 Farzi Cafe        10098
# ...                         ...          ...
# 5042      Pritam Tiffin Service            0
# 5033   Prerna Family Restaurant            0
# 5031                 Prem Rasoi            0
# 5029         Prem Ji Delhi Wale            0
# 3722                Laxmi Dairy            0
#
# [7445 rows x 2 columns]

# %%
plt.figure(figsize=(8, 4))
plt.barh(Votes["Restaurant Name"][:10], Votes["Total Votes"][:10],color='pink', edgecolor='black')
plt.title("Top 10 Restaurant Chains by Total Votes")
plt.xlabel("Total Votes")
plt.ylabel("Restaurant Chains")
plt.show()
